# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

amazon=pd.read_csv("amazon_prime_users.csv", index_col=0, na_values=['??','????'])

amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2500 entries, 1 to 2500
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Name                           2500 non-null   object
#  1   Email Address                  2500 non-null   object
#  2   Username                       2500 non-null   object
#  3   Date of Birth                  2500 non-null   object
#  4   Gender                         2500 non-null   object
#  5   Location                       2500 non-null   object
#  6   Membership Start Date          2500 non-null   object
#  7   Membership End Date            2500 non-null   object
#  8   Subscription Plan              2500 non-null   object
#  9   Payment Information            2500 non-null   object
#  10  Renewal Status                 2500 non-null   object
#  11  Usage Frequency                2500 non-null   object
# ...

# %%
amazon.dropna(axis=0,inplace=True)
amazon
# Out:
#                      Name                   Email Address            Username  \
# User ID
# 1           Ronald Murphy      williamholland@example.com      williamholland
# 2             Scott Allen             scott22@example.org             scott22
# 3        Jonathan Parrish            brooke16@example.org            brooke16
# 4          Megan Williams         elizabeth31@example.net         elizabeth31
# 5           Kathryn Brown  pattersonalexandra@example.org  pattersonalexandra
# ...                   ...                             ...                 ...
# 2496        Michael Lopez     williamsroberto@example.org     williamsroberto
# 2497      Matthew Woodard             lkaiser@example.com             lkaiser
# 2498        Morgan Barnes        erikaholland@example.net        erikaholland
# 2499       Gina Castaneda        reedcourtney@example.net        reedcourtney
# 2500       Mark Nicholson         martinisaac@example.net         martinisaac
#
# ...

# %%
plt.hist(amazon['Favorite Genres'],color='green',edgecolor='white', bins=30) #microscopic view
plt.title('Histogram of Favorite Genres')
plt.xlabel('Favorite Genres')
plt.ylabel('Frequency')
plt.show()
